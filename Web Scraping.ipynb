# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get('https://www.flipkart.com/search?q=iphone%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off')
c = r.content

# %%
soup = BeautifulSoup(c,'html.parser')

# %%
#soup

# %%
all = soup.find_all('div',{'class':'_3O0U0u'})
#all

# %%
len(all)
# Out:
# 24

# %%
del(all[12])

# %%
l = []
for item in all:
    d = {}
    l1 = []
    d['Name']=item.find('div',{'class':'_3wU53n'}).text
    d['Price']=item.find('div',{'class':'_1vC4OE _2rQ-NK'}).text
    d['Rating']=item.find('div',{'class':'hGSR34'}).text
    l1 = item.find('div',{'class':'_3ULzGw'}).text.split('|')
    d['Storage'] = l1[0].strip()
    d['Display'] = l1[1][0:20].strip()
    d['Rear_Camera'] = l1[1].split('Display')[1].split(' ')[0]
    d['Front_Camera'] = l1[2].split(' ')[1]
    l.append(d)
       
l
# Out:
# [{'Name': 'Apple iPhone 6 (Gold, 32 GB)',
#   'Price': '₹21,999',
#   'Rating': '4.4',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '8MP',
#   'Front_Camera': '1.2MP'},
#  {'Name': 'Apple iPhone 8 (PRODUCT)RED (Red, 64 GB)',
#   'Price': '₹59,990',
#   'Rating': '4.7',
#   'Storage': '64 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 6s (Rose Gold, 32 GB)',
#   'Price': '₹27,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 6s (Space Grey, 32 GB)',
#   'Price': '₹27,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 7 (Black, 32 GB)',
#   'Price': '₹37,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 7 (Rose Gold, 32 GB)',
#   'Price': '₹37,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 6s (Gold, 32 GB)',
#   'Price': '₹27,999',
#   'Rating': '4.4',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 6s Plus (Gold, 32 GB)',
#   'Price': '₹33,999',
#   'Rating': '4.4',
#   'Storage': '32 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 7 (Gold, 32 GB)',
#   'Price': '₹37,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone XR (Black, 64 GB)',
#   'Price': '₹67,999',
#   'Rating': '4.6',
#   'Storage': '64 GB ROM',
#   'Display': '15.49 cm (6.1 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone XR (White, 64 GB)',
#   'Price': '₹67,999',
#   'Rating': '4.6',
#   'Storage': '64 GB ROM',
#   'Display': '15.49 cm (6.1 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone XR (Coral, 64 GB)',
#   'Price': '₹67,999',
#   'Rating': '4.6',
#   'Storage': '64 GB ROM',
#   'Display': '15.49 cm (6.1 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 7 (Silver, 32 GB)',
#   'Price': '₹37,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 6s (Silver, 32 GB)',
#   'Price': '₹27,999',
#   'Rating': '4.4',
#   'Storage': '32 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone XR (Blue, 64 GB)',
#   'Price': '₹67,999',
#   'Rating': '4.6',
#   'Storage': '64 GB ROM',
#   'Display': '15.49 cm (6.1 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone XR (Black, 128 GB)',
#   'Price': '₹72,999',
#   'Rating': '4.6',
#   'Storage': '128 GB ROM',
#   'Display': '15.49 cm (6.1 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 7 Plus (Black, 32 GB)',
#   'Price': '₹48,999',
#   'Rating': '4.6',
#   'Storage': '32 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 6s Plus (Space Grey, 32 GB)',
#   'Price': '₹33,999',
#   'Rating': '4.5',
#   'Storage': '32 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 7 Plus (Gold, 32 GB)',
#   'Price': '₹48,999',
#   'Rating': '4.6',
#   'Storage': '32 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 6s Plus (Rose Gold, 32 GB)',
#   'Price': '₹33,999',
#   'Rating': '4.4',
#   'Storage': '32 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 6s Plus (Space Grey, 16 GB)',
#   'Price': '₹42,900',
#   'Rating': '4.4',
#   'Storage': '16 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '5MP'},
#  {'Name': 'Apple iPhone 8 Plus (Gold, 64 GB)',
#   'Price': '₹66,999',
#   'Rating': '4.6',
#   'Storage': '64 GB ROM',
#   'Display': '13.97 cm (5.5 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'},
#  {'Name': 'Apple iPhone 8 (Space Grey, 64 GB)',
#   'Price': '₹56,999',
#   'Rating': '4.5',
#   'Storage': '64 GB ROM',
#   'Display': '11.94 cm (4.7 inch)',
#   'Rear_Camera': '12MP',
#   'Front_Camera': '7MP'}]

# %%
df = pd.DataFrame(l)

# %%
df.head(5)
# Out:
#                Display Front_Camera                                      Name  \
# 0  11.94 cm (4.7 inch)        1.2MP              Apple iPhone 6 (Gold, 32 GB)
# 1  11.94 cm (4.7 inch)          7MP  Apple iPhone 8 (PRODUCT)RED (Red, 64 GB)
# 2  11.94 cm (4.7 inch)          5MP        Apple iPhone 6s (Rose Gold, 32 GB)
# 3  11.94 cm (4.7 inch)          5MP       Apple iPhone 6s (Space Grey, 32 GB)
# 4  11.94 cm (4.7 inch)          7MP             Apple iPhone 7 (Black, 32 GB)
#
#      Price Rating Rear_Camera    Storage
# 0  ₹21,999    4.4         8MP  32 GB ROM
# 1  ₹59,990    4.7        12MP  64 GB ROM
# 2  ₹27,999    4.5        12MP  32 GB ROM
# 3  ₹27,999    4.5        12MP  32 GB ROM
# 4  ₹37,999    4.5        12MP  32 GB ROM

# %%
df.to_csv('iPhone.csv')
